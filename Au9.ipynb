# %% [markdown]
# 1- Abrindo arquivo

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

df_train = pd.read_csv("C:/Utilidades/Python/Aulas/df_train.csv")
df_train
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch    Fare  Embarked
# 0           0       3  0.0  22.000000      1      0   7.250       1.0
# 1           1       1  1.0  38.000000      1      0  40.000       2.0
# 2           1       3  1.0  26.000000      0      0   7.925       1.0
# 3           1       1  1.0  35.000000      1      0  40.000       1.0
# 4           0       3  0.0  35.000000      0      0   8.050       1.0
# ..        ...     ...  ...        ...    ...    ...     ...       ...
# 886         0       2  0.0  27.000000      0      0  13.000       1.0
# 887         1       1  1.0  19.000000      0      0  30.000       1.0
# 888         0       3  1.0  29.699118      1      2  23.450       1.0
# 889         1       1  0.0  26.000000      0      0  30.000       2.0
# 890         0       3  0.0  32.000000      0      0   7.750       0.0
#
# [891 rows x 8 columns]

# %% [markdown]
# 2- Separando as colunas nas variaveis Y e X

# %%
X = df_train.loc[:,"Pclass":"Embarked"]
Y = df_train.loc[:,"Survived"]
print(f"Valores de X:\n{X} \n\nValores de Y\n{Y}")
# Out:
# Valores de X:
#      Pclass  Sex        Age  SibSp  Parch    Fare  Embarked
# 0         3  0.0  22.000000      1      0   7.250       1.0
# 1         1  1.0  38.000000      1      0  40.000       2.0
# 2         3  1.0  26.000000      0      0   7.925       1.0
# 3         1  1.0  35.000000      1      0  40.000       1.0
# 4         3  0.0  35.000000      0      0   8.050       1.0
# ..      ...  ...        ...    ...    ...     ...       ...
# 886       2  0.0  27.000000      0      0  13.000       1.0
# 887       1  1.0  19.000000      0      0  30.000       1.0
# 888       3  1.0  29.699118      1      2  23.450       1.0
# 889       1  0.0  26.000000      0      0  30.000       2.0
# 890       3  0.0  32.000000      0      0   7.750       0.0
#
# [891 rows x 7 columns]
#
# Valores de Y
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# 3- Separando os grupos de Treino e Teste

# %%
X_train, X_teste, Y_train, Y_teste = train_test_split(X, Y)

X_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 398       2  0.0  23.0      0      0  10.5000       1.0
# 626       2  0.0  57.0      0      0  12.3500       0.0
# 770       3  0.0  24.0      0      0   9.5000       1.0
# 433       3  0.0  17.0      0      0   7.1250       1.0
# 471       3  0.0  38.0      0      0   8.6625       1.0
# ..      ...  ...   ...    ...    ...      ...       ...
# 716       1  1.0  38.0      0      0  40.0000       2.0
# 520       1  1.0  30.0      0      0  40.0000       1.0
# 162       3  0.0  26.0      0      0   7.7750       1.0
# 112       3  0.0  22.0      0      0   8.0500       1.0
# 567       3  1.0  29.0      0      4  21.0750       1.0
#
# [668 rows x 7 columns]

# %% [markdown]
# 4- Colocando KNN em uma variável

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %% [markdown]
# 5- Fazendo uma predição

# %%
knn.fit(X_train, Y_train)
y_pred = knn.predict(X_teste)
print("Precissão do algoritimo, com k=5:", accuracy_score(Y_teste, y_pred)*100)
# Out:
# Precissão do algoritimo, com k=5: 69.05829596412556
